# %% [markdown]
# ## SOLAR POWER PREDICTION USING LINEAR REGRESSION

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import seaborn as sns

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
pip install seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# load the dataset
df = pd.read_csv('solarpowergeneration.csv')
# display the first few rows of the dataset
df.head()
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# 2                       1035.4                      0.0                  0.0
# 3                       1035.4                      0.0                  0.0
# 4                       1034.4                      0.0                  0.0
#
#    total_cloud_cover_sfc  high_cloud_cover_high_cld_lay  \
# 0                    0.0                              0
# ...

# %%
df.tail()
# Out:
#       temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 4208                       8.69                               66
# 4209                       7.57                               90
# 4210                       7.27                               90
# 4211                       8.25                               81
# 4212                       8.00                               80
#
#       mean_sea_level_pressure_MSL  total_precipitation_sfc  \
# 4208                       1025.1                      0.0
# 4209                       1026.1                      0.0
# 4210                       1026.3                      0.1
# 4211                       1025.5                      0.0
# 4212                       1025.3                      0.0
#
#       snowfall_amount_sfc  total_cloud_cover_sfc  \
# 4208                  0.0                  100.0
# 4209                  0.0                  100.0
# 4210                  0.0                  100.0
# ...

# %%
df.head(10)
# Out:
#    temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                       2.17                               31
# 1                       2.31                               27
# 2                       3.65                               33
# 3                       5.82                               30
# 4                       7.73                               27
# 5                       8.69                               29
# 6                       9.72                               27
# 7                      10.07                               28
# 8                       9.38                               32
# 9                       6.54                               47
#
#    mean_sea_level_pressure_MSL  total_precipitation_sfc  snowfall_amount_sfc  \
# 0                       1035.0                      0.0                  0.0
# 1                       1035.1                      0.0                  0.0
# ...

# %%
# to check the total number of rows and columns
df.shape
# Out:
# (4213, 21)

# %%
# display summary
df.describe()
# Out:
#        temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# count                4213.000000                      4213.000000
# mean                   15.068111                        51.361025
# std                     8.853677                        23.525864
# min                    -5.350000                         7.000000
# 25%                     8.390000                        32.000000
# 50%                    14.750000                        48.000000
# 75%                    21.290000                        70.000000
# max                    34.900000                       100.000000
#
#        mean_sea_level_pressure_MSL  total_precipitation_sfc  \
# count                  4213.000000              4213.000000
# mean                   1019.337812                 0.031759
# std                       7.022867                 0.170212
# min                     997.500000                 0.000000
# 25%                    1014.500000                 0.000000
# ...

# %%
# to get the information of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4213 entries, 0 to 4212
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   temperature_2_m_above_gnd          4213 non-null   float64
#  1   relative_humidity_2_m_above_gnd    4213 non-null   int64
#  2   mean_sea_level_pressure_MSL        4213 non-null   float64
#  3   total_precipitation_sfc            4213 non-null   float64
#  4   snowfall_amount_sfc                4213 non-null   float64
#  5   total_cloud_cover_sfc              4213 non-null   float64
#  6   high_cloud_cover_high_cld_lay      4213 non-null   int64
#  7   medium_cloud_cover_mid_cld_lay     4213 non-null   int64
#  8   low_cloud_cover_low_cld_lay        4213 non-null   int64
#  9   shortwave_radiation_backwards_sfc  4213 non-null   float64
#  10  wind_speed_10_m_above_gnd          4213 non-null   float64
# ...

# %%
# check for the missing values
df.isnull()
# Out:
#       temperature_2_m_above_gnd  relative_humidity_2_m_above_gnd  \
# 0                         False                            False
# 1                         False                            False
# 2                         False                            False
# 3                         False                            False
# 4                         False                            False
# ...                         ...                              ...
# 4208                      False                            False
# 4209                      False                            False
# 4210                      False                            False
# 4211                      False                            False
# 4212                      False                            False
#
#       mean_sea_level_pressure_MSL  total_precipitation_sfc  \
# 0                           False                    False
# 1                           False                    False
# ...

# %%
# check for the missing values
df.isnull().sum()
# Out:
# temperature_2_m_above_gnd            0
# relative_humidity_2_m_above_gnd      0
# mean_sea_level_pressure_MSL          0
# total_precipitation_sfc              0
# snowfall_amount_sfc                  0
# total_cloud_cover_sfc                0
# high_cloud_cover_high_cld_lay        0
# medium_cloud_cover_mid_cld_lay       0
# low_cloud_cover_low_cld_lay          0
# shortwave_radiation_backwards_sfc    0
# wind_speed_10_m_above_gnd            0
# wind_direction_10_m_above_gnd        0
# wind_speed_80_m_above_gnd            0
# wind_direction_80_m_above_gnd        0
# wind_speed_900_mb                    0
# wind_direction_900_mb                0
# wind_gust_10_m_above_gnd             0
# angle_of_incidence                   0
# zenith                               0
# azimuth                              0
# generated_power_kw                   0
# dtype: int64

# %%
# check duplicate values
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
import matplotlib.pyplot as plt

# %%
# plot distribution of power
plt.figure(figsize=(10,6))
sns.histplot()
# Out:
# <Axes: >

# %%
plt.Figure(figsize=(10,6))
sns.histplot(df['generated_power_kw'], bins=30, kde=True)
plt.title('distribution of generated power (kw)')
plt.xlabel('Generated power (kw)')
plt.ylabel('frequency')
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Histogram: Distribution of temperature
plt.figure(figsize=(10, 6))
sns.histplot(df['temperature_2_m_above_gnd'], bins=30, kde=True, color='skyblue')
plt.title('Distribution of Temperature (2m above ground)')
plt.xlabel('Temperature (°C)')
plt.ylabel('Frequency')
plt.show()

# %%
# Scatter Plot: Generated power vs wind speed
plt.figure(figsize=(10, 6))
sns.scatterplot(data=df, x='wind_speed_10_m_above_gnd', y='generated_power_kw', alpha=0.7, color='green')
plt.title('Generated Power vs Wind Speed (10m above ground)')
plt.xlabel('Wind Speed (m/s)')
plt.ylabel('Generated Power (kW)')
plt.show()

# %%
# Box Plot: Total precipitation by cloud cover levels
plt.figure(figsize=(10, 6))
sns.boxplot(data=df, x='total_cloud_cover_sfc', y='total_precipitation_sfc', palette='Set3')
plt.title('Total Precipitation vs Cloud Cover')
plt.xlabel('Total Cloud Cover (%)')
plt.ylabel('Total Precipitation (mm)')
plt.show()
# Out:
# C:\Users\Shruti\AppData\Local\Temp\ipykernel_15584\2962311399.py:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(data=df, x='total_cloud_cover_sfc', y='total_precipitation_sfc', palette='Set3')

# %%
# Line Plot: Wind speed and power generation
plt.figure(figsize=(10, 6))
sns.lineplot(data=df, x='wind_speed_80_m_above_gnd', y='generated_power_kw', color='orange')
plt.title('Generated Power vs Wind Speed (80m above ground)')
plt.xlabel('Wind Speed (m/s)')
plt.ylabel('Generated Power (kW)')
plt.show()

# %%
# Heatmap: Correlation matrix
plt.figure(figsize=(12, 8))
correlation_matrix = df.corr()
sns.heatmap(correlation_matrix, annot=True, fmt='.2f', cmap='coolwarm')
plt.title('Correlation Matrix of Features')
plt.show()

# %% [markdown]
# ### eda

# %%
#histograms for remaining columns

# %%
df[df.columns[:9]].hist(bins=30 , figsize= (15 , 10))
plt.show()

# %%
df[df.columns[9:18]].hist(bins=30 , figsize=(15,10))
plt.show()

# %%
df[df.columns[18:20]].hist(bins=30 , figsize =(15, 10))
plt.show()

# %%
#bivariate analysis
# Scatter plot with target feature
plt.figure(figsize= (15,30))
for i , column in enumerate(df.columns):
    plt.subplot(7, 3, i+1)
    plt.scatter(df[column], df['generated_power_kw'])
    plt.title(f'{column} vs Generated Power (kw)')
    plt.xlabel(column)
    plt.ylabel('Generated Power (kw)')
plt.tight_layout()
plt.show()

# %%
df.corr()
# Out:
#                                    temperature_2_m_above_gnd  \
# temperature_2_m_above_gnd                           1.000000
# relative_humidity_2_m_above_gnd                    -0.771704
# mean_sea_level_pressure_MSL                        -0.402240
# total_precipitation_sfc                            -0.083137
# snowfall_amount_sfc                                -0.121422
# total_cloud_cover_sfc                              -0.326641
# high_cloud_cover_high_cld_lay                      -0.019522
# medium_cloud_cover_mid_cld_lay                     -0.100980
# low_cloud_cover_low_cld_lay                        -0.381876
# shortwave_radiation_backwards_sfc                   0.665755
# wind_speed_10_m_above_gnd                          -0.172532
# wind_direction_10_m_above_gnd                       0.051393
# wind_speed_80_m_above_gnd                          -0.244869
# wind_direction_80_m_above_gnd                       0.086630
# ...

# %%
plt.figure(figsize =(15,10))
#fmt is 
sns.heatmap(df.corr() , cmap ='coolwarm' , annot= True , fmt ='.2f')
plt.show()

# %%
#outlier
plt.figure(figsize=(15 , 30))
for i , column in enumerate(df.columns):
    plt.subplot(7, 3, i+1)
    sns.boxplot(df[column])
plt.show()

# %%
df.corr('pearson')
# Out:
#                                    temperature_2_m_above_gnd  \
# temperature_2_m_above_gnd                           1.000000
# relative_humidity_2_m_above_gnd                    -0.771704
# mean_sea_level_pressure_MSL                        -0.402240
# total_precipitation_sfc                            -0.083137
# snowfall_amount_sfc                                -0.121422
# total_cloud_cover_sfc                              -0.326641
# high_cloud_cover_high_cld_lay                      -0.019522
# medium_cloud_cover_mid_cld_lay                     -0.100980
# low_cloud_cover_low_cld_lay                        -0.381876
# shortwave_radiation_backwards_sfc                   0.665755
# wind_speed_10_m_above_gnd                          -0.172532
# wind_direction_10_m_above_gnd                       0.051393
# wind_speed_80_m_above_gnd                          -0.244869
# wind_direction_80_m_above_gnd                       0.086630
# ...

# %%
df.corr('spearman')
# Out:
#                                    temperature_2_m_above_gnd  \
# temperature_2_m_above_gnd                           1.000000
# relative_humidity_2_m_above_gnd                    -0.780716
# mean_sea_level_pressure_MSL                        -0.402478
# total_precipitation_sfc                            -0.113468
# snowfall_amount_sfc                                -0.168743
# total_cloud_cover_sfc                              -0.297001
# high_cloud_cover_high_cld_lay                      -0.028867
# medium_cloud_cover_mid_cld_lay                     -0.051851
# low_cloud_cover_low_cld_lay                        -0.356894
# shortwave_radiation_backwards_sfc                   0.660141
# wind_speed_10_m_above_gnd                          -0.083848
# wind_direction_10_m_above_gnd                       0.042216
# wind_speed_80_m_above_gnd                          -0.184233
# wind_direction_80_m_above_gnd                       0.077669
# ...

# %%
plt.figure(figsize=(8, 5))
sns.scatterplot(x=df["total_precipitation_sfc"], y=df["generated_power_kw"])  # Replace with actual column names
plt.xlabel("X values")
plt.ylabel("Y values")
plt.title("Scatter Plot to Identify Outliers")
plt.show()

# %%
plt.figure(figsize=(15, 30))
sns.heatmap(df.corr(), annot=True, cmap="Set1", linewidths=2)
plt.title("Correlation Heatmap")
plt.show()
